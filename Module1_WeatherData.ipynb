# %%
from glob import glob
import os
import pandas as pd
import json

# %%
w0files = sorted(glob('Data\\weather\\***\\2016-*.json'))

# %%
w1files = sorted(glob('Data\\weather\\***\\2017-*.json'))

# %%
airports = ['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO']

# %%
weather_data1 = []
for i in w1files:
    with open(i) as f:
        temp = json.load(f)
        for k in temp['data']['weather']:
            tempdata1 = pd.DataFrame(k['hourly'],columns=['windspeedKmph','visibility','weatherCode','precipMM','WindGustKmph','pressure','cloudcover','winddirDegree','humidity','DewPointF','tempF','time','WindChillF'])
            tempdata1['date'] = k['date']
            for a in airports:
                if a in i.split('\\'):
                    tempdata1['place'] = a 
            weather_data1 = pd.DataFrame(weather_data1.append(tempdata1))
weather_data1.reset_index()
# Out:
#         index windspeedKmph visibility weatherCode precipMM WindGustKmph  \
# 0           0             8          7         353      6.1           16
# 1           1             8          7         353      5.1           16
# 2           2             7          8         356      4.1           15
# 3           3             7          9         356      3.1           14
# 4           4             6          8         356      4.1           13
# ...       ...           ...        ...         ...      ...          ...
# 131371     19            26         10         113      0.0           27
# 131372     20            26         10         113      0.0           27
# 131373     21            26         10         113      0.0           27
# 131374     22            23         10         113      0.0           25
# 131375     23            20         10         113      0.0           22
#
#        pressure cloudcover winddirDegree humidity DewPointF tempF  time  \
# 0          1021        100           100       97        50    51     0
# 1          1020        100            99       97        50    51   100
# 2          1020        100            99       98        51    52   200
# 3          1020        100            99       98        51    52   300
# 4          1020        100            92       98        52    52   400
# ...         ...        ...           ...      ...       ...   ...   ...
# 131371     1014          0           296       70        57    67  1900
# 131372     1014          0           298       71        58    67  2000
# 131373     1014          0           300       73        58    67  2100
# 131374     1014          0           302       74        58    66  2200
# 131375     1014          0           303       75        58    66  2300
#
#        WindChillF        date place
# 0              49  2017-01-02   ATL
# 1              50  2017-01-02   ATL
# 2              50  2017-01-02   ATL
# 3              51  2017-01-02   ATL
# 4              52  2017-01-02   ATL
# ...           ...         ...   ...
# 131371         67  2017-09-30   SFO
# 131372         67  2017-09-30   SFO
# 131373         67  2017-09-30   SFO
# 131374         66  2017-09-30   SFO
# 131375         66  2017-09-30   SFO
#
# [131376 rows x 16 columns]

# %%
weather_data1.to_csv('Data\\weather17.csv')

# %%
weather_data0 = []
for i in w0files:
    with open(i) as f:
        temp = json.load(f)
        for k in temp['data']['weather']:
            tempdata0 = pd.DataFrame(k['hourly'],columns=['windspeedKmph','visibility','weatherCode','precipMM','WindGustKmph','pressure','cloudcover','winddirDegree','humidity','DewPointF','tempF','time','WindChillF'])
            tempdata0['date'] = k['date']
            for a in airports:
                if a in i.split('\\'):
                    tempdata0['place'] = a 
            weather_data0 = pd.DataFrame(weather_data0.append(tempdata0))
weather_data0.reset_index()
# Out:
#         index windspeedKmph visibility weatherCode precipMM WindGustKmph  \
# 0           0            15         10         122      0.0           23
# 1           1            16         10         122      0.0           23
# 2           2            16         10         116      0.0           23
# 3           3            16         10         116      0.0           23
# 4           4            16         10         116      0.0           23
# ...       ...           ...        ...         ...      ...          ...
# 131731     19            22         10         116      0.0           26
# 131732     20            21         10         119      0.0           25
# 131733     21            21         10         119      0.0           24
# 131734     22            20         10         119      0.0           23
# 131735     23            19         10         122      0.0           23
#
#        pressure cloudcover winddirDegree humidity DewPointF tempF  time  \
# 0          1026         86           319       76        33    40     0
# 1          1026         81           320       78        33    39   100
# 2          1026         76           321       80        33    38   200
# 3          1026         71           322       83        33    38   300
# 4          1026         79           319       83        32    37   400
# ...         ...        ...           ...      ...       ...   ...   ...
# 131731     1020         51           289       80        51    58  1900
# 131732     1020         64           291       85        52    57  2000
# 131733     1020         77           293       90        54    56  2100
# 131734     1020         81           294       91        54    56  2200
# 131735     1020         86           296       92        54    56  2300
#
#        WindChillF        date place
# 0              34  2016-01-02   ATL
# 1              33  2016-01-02   ATL
# 2              32  2016-01-02   ATL
# 3              31  2016-01-02   ATL
# 4              30  2016-01-02   ATL
# ...           ...         ...   ...
# 131731         55  2016-09-30   SFO
# 131732         54  2016-09-30   SFO
# 131733         53  2016-09-30   SFO
# 131734         53  2016-09-30   SFO
# 131735         53  2016-09-30   SFO
#
# [131736 rows x 16 columns]

# %%
weather_data0.to_csv('Data\\weather16.csv')

# %%
weather_df = pd.concat([weather_data0,weather_data1])
weather_df.to_csv('Data\\Weather_Data.csv')
